# %% [markdown]
# <a href="https://colab.research.google.com/github/HannaAnggraini06/EDA-Tugas-1/blob/main/Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. PRAKTIKUM 01**

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd

file_name = list(uploaded.keys())[0]
df = pd.read_excel(file_name)

df = df.reset_index(drop=True)
df.index = df.index + 1

display(df.head())
# Out:
#      <input type="file" id="files-809bd21f-dc63-419b-9f99-78070274146b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-809bd21f-dc63-419b-9f99-78070274146b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print("Ukuran dataset (baris, kolom): ", df.shape)

print("Jumlah total elemen : ", df.size)
# Out:
# Ukuran dataset (baris, kolom):  (6707, 6)
# Jumlah total elemen :  40242

# %%
my_variable = "Hello"
print("Tipe data my_variable : ", type(my_variable))
# Out:
# Tipe data my_variable :  <class 'str'>

# %%
my_number = 123
print("Tipe data my_number : ", type(my_number))
# Out:
# Tipe data my_number :  <class 'int'>

# %%
print("\nTipe data setiap kolom dalam DataFrame : ")
print(df.dtypes)
# Out:
# Tipe data setiap kolom dalam DataFrame :
# Age                      int64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
missing_values = df.isnull().sum()
print("Jumlah nilai yang hilang di setiap kolom : ")
print(missing_values)
# Out:
# Jumlah nilai yang hilang di setiap kolom :
# Age                    0
# Gender                 0
# Education Level        1
# Job Title              1
# Years of Experience    2
# Salary                 4
# dtype: int64

# %%
duplicate_rows_count = df.duplicated().sum()
print(f"Jumlah baris duplikat : {duplicate_rows_count}")

if duplicate_rows_count > 0:
  print("\nBeberapa baris duplikat pertama : ")
  display(df[df.duplicated(keep=False)].head())
# Out:
# Jumlah baris duplikat : 4913
#
# Beberapa baris duplikat pertama :
#      Age  Gender Education Level                     Job Title  \
# 1     32    Male      Bachelor's             Software Engineer
# 2     28  Female        Master's                  Data Analyst
# 141   28    Male      Bachelor's       Junior Business Analyst
# 195   28    Male      Bachelor's       Junior Business Analyst
# 209   30  Female      Bachelor's  Junior Marketing Coordinator
#
#      Years of Experience   Salary
# 1                    5.0  90000.0
# 2                    3.0  65000.0
# 141                  2.0  40000.0
# 195                  2.0  40000.0
# 209                  2.0  40000.0

# %% [markdown]
# **2. PRAKTIKUM 02**

# %%
numerical_df = df.select_dtypes(include=['int64', 'float64'])

descriptive_stats = numerical_df.describe()
median_values = numerical_df.median()
mode_values = numerical_df.mode().iloc[0]
mad_values = numerical_df.apply(lambda x: (x - x.mean()).abs().mean())
range_values = numerical_df.max() - numerical_df.min()
variance_values = numerical_df.var()


descriptive_stats.loc['Median'] = median_values
descriptive_stats.loc['Mode'] = mode_values
descriptive_stats.loc['MAD'] = mad_values
descriptive_stats.loc['Range'] = range_values
descriptive_stats.loc['Variance'] = variance_values

print("ringkasan statistik deskriptif")
display(descriptive_stats)
# Out:
# ringkasan statistik deskriptif
#                   Age  Years of Experience        Salary
# count     6707.000000          6705.000000  6.703000e+03
# mean        33.623677             8.096346  1.154461e+05
# std          7.621529             6.067248  5.388179e+04
# min         21.000000             0.000000  3.500000e+02
# 25%         28.000000             3.000000  7.000000e+04
# 50%         32.000000             7.000000  1.150000e+05
# 75%         38.000000            12.000000  1.600000e+05
# max         62.000000            35.000000  1.000000e+06
# Median      32.000000             7.000000  1.150000e+05
# Mode        27.000000             2.000000  1.400000e+05
# MAD          6.137041             4.896342  4.586885e+04
# Range       41.000000            35.000000  9.996500e+05
# Variance    58.087707            36.811495  2.903247e+09

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols_scatter = ['Years of Experience', 'Salary']
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x=numerical_cols_scatter[0], y=numerical_cols_scatter[1], hue='Age', alpha=0.6)
plt.title(f'Scatter plot of {numerical_cols_scatter[0]} vs {numerical_cols_scatter[1]}')
plt.xlabel(numerical_cols_scatter[0])
plt.ylabel(numerical_cols_scatter[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# **3. PRAKTIKUM 03**

# %%
print("Lima baris pertama dari DataFrame : ")
display(df.head())

print("\nInformasi tentang DataFrame")
df.info()

print("\nJumlah nilai yang hilang di setiap kolom : ")
print(df.isnull().sum())
# Out:
# Lima baris pertama dari DataFrame :
#    Age  Gender Education Level          Job Title  Years of Experience  \
# 1   32    Male      Bachelor's  Software Engineer                  5.0
# 2   28  Female        Master's       Data Analyst                  3.0
# 3   45    Male             PhD     Senior Manager                  NaN
# 4   36  Female      Bachelor's    Sales Associate                  7.0
# 5   52    Male        Master's           Director                 20.0
#
#      Salary
# 1   90000.0
# 2   65000.0
# 3  150000.0
# 4   60000.0
# 5  200000.0
# Informasi tentang DataFrame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6707 entries, 1 to 6707
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6707 non-null   int64
#  1   Gender               6707 non-null   object
#  2   Education Level      6706 non-null   object
# ...

# %%
status_mode = df['Salary'].mode()[0]
print(f"Modus dari kolom 'Salary' : {status_mode}")
# Out:
# Modus dari kolom 'Salary' : 140000.0

# %%
df['Salary'] = df['Salary'].fillna(status_mode)

# %%
missing_values_after_fill = df['Salary'].isnull().sum()
print(f"\nJumlah nilai yang hilang di kolom Status setelah pengisian : {missing_values_after_fill}")
# Out:
# Jumlah nilai yang hilang di kolom Status setelah pengisian : 0

# %%
duplicate_rows_count = df.duplicated().sum()

print(f"Jumlah baris duplikat : {duplicate_rows_count}")

if duplicate_rows_count > 0:
    print("\nMenghapus baris duplikat... ")
    df = df.drop_duplicates()
    print("Baris duplikat telah dihapus.")

    duplicate_rows_count_after_deletion = df.duplicated().sum()
    print(f"\nJumlah baris duplikat setelah penghapusan : {duplicate_rows_count_after_deletion}")

    if duplicate_rows_count > 0:
      print("\nBeberapa baris pertama DataFrame setelah penghapusan duplikat : ")

    display(df.head())
# Out:
# Jumlah baris duplikat : 4913
#
# Menghapus baris duplikat...
# Baris duplikat telah dihapus.
#
# Jumlah baris duplikat setelah penghapusan : 0
#
# Beberapa baris pertama DataFrame setelah penghapusan duplikat :
#    Age  Gender Education Level          Job Title  Years of Experience  \
# 1   32    Male      Bachelor's  Software Engineer                  5.0
# 2   28  Female        Master's       Data Analyst                  3.0
# 3   45    Male             PhD     Senior Manager                  NaN
# 4   36  Female      Bachelor's    Sales Associate                  7.0
# 5   52    Male        Master's           Director                 20.0
#
#      Salary
# 1   90000.0
# 2   65000.0
# 3  150000.0
# 4   60000.0
# 5  200000.0

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

print("Memeriksa nilai unik dan distribusi untuk kolom kategorikal : ")
for col in categorical_cols:
  print(f"\nKolom : {col}")
  print(df[col].value_counts())

  numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("\nMemeriksa nilai unik dan distribusi untuk kolom numerikal : ")
display(df[numerical_cols].describe())
# Out:
# Memeriksa nilai unik dan distribusi untuk kolom kategorikal :
#
# Kolom : Gender
# Gender
# Male      971
# Female    816
# Other       7
# Name: count, dtype: int64
#
# Kolom : Education Level
# Education Level
# Bachelor's Degree    508
# Master's Degree      447
# PhD                  342
# Bachelor's           263
# Master's             122
# High School          110
# phD                    1
# Name: count, dtype: int64
#
# Kolom : Job Title
# Job Title
# Software Engineer Manager    127
# Full Stack Engineer          123
# Senior Software Engineer      96
# Senior Project Engineer       95
# Back end Developer            81
#                             ...
# Developer                      1
# Social M                       1
# Social Media Man               1
# Delivery Driver                1
# Intern                         1
# Name: count, Length: 194, dtype: int64
#
# Memeriksa nilai unik dan distribusi untuk kolom numerikal :
# ...

# %%
df['Job Title'] = df['Job Title'].str.lower().str.strip()

print("\nDistribusi kolom 'Job Title' setelah standarisasi : ")
print(df['Job Title'].value_counts())

import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols_outliers = ['Age', 'Salary']
plt.figure(figsize=(10, 5))
for i, col in enumerate(numerical_cols_outliers, 1):
  plt.subplot(1, 2, i)
  sns.boxplot(data=df, y=col)
  plt.title(f'Boxplot of {col}')
  plt.ylabel(col)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2435464337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Job Title'] = df['Job Title'].str.lower().str.strip()
# Distribusi kolom 'Job Title' setelah standarisasi :
# Job Title
# software engineer manager    127
# full stack engineer          123
# senior software engineer      96
# senior project engineer       95
# back end developer            81
#                             ...
# developer                      1
# social m                       1
# social media man               1
# delivery driver                1
# intern                         1
# Name: count, Length: 193, dtype: int64

# %%
upper_limit = 20000000
df['Salary'] = df['Salary'].clip(upper=upper_limit)

print(f"\nStatistik deskriptif untuk 'Salary' setelah capping (upper_limit = {upper_limit}) : ")

display(df['Salary'].describe())

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, y='Salary')
plt.title('Boxplot of Salary')
plt.ylabel('Salary')
plt.tight_layout()
plt.show()
# Out:
# Statistik deskriptif untuk 'Salary' setelah capping (upper_limit = 20000000) :
# /tmp/ipython-input-2915652527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary'] = df['Salary'].clip(upper=upper_limit)
# count       1794.000000
# mean      113726.860089
# std        55647.459021
# min          350.000000
# 25%        70000.000000
# 50%       110353.500000
# 75%       160000.000000
# max      1000000.000000
# Name: Salary, dtype: float64

# %%
df['Years of Experience'] = pd.to_datetime(df['Years of Experience'])
df['Tahun_Daftar'] = df['Years of Experience'].dt.year
df['Bulan_Daftar'] = df['Years of Experience'].dt.month
df['Hari_Daftar'] = df['Years of Experience'].dt.day

display(df.head())
# Out:
# /tmp/ipython-input-4051186612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Years of Experience'] = pd.to_datetime(df['Years of Experience'])
# /tmp/ipython-input-4051186612.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tahun_Daftar'] = df['Years of Experience'].dt.year
# /tmp/ipython-input-4051186612.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
output_file_name = 'Salary_Data_Tugas.xlsx'
df.to_excel(output_file_name, index=False)

print(f"DataFrame telah berhasil disimpan ke '{output_file_name}'")
# Out:
# DataFrame telah berhasil disimpan ke 'Salary_Data_Tugas.xlsx'

# %%
missing_values_before_drop = df.isnull().sum()
print(f"Jumlah nilai yang hilang sebelum penghapusan :  {missing_values_before_drop}")

df_dropped = df.dropna(subset=['Salary']).copy()

missing_values_after_drop = df_dropped['Salary'].isnull().sum()
print(f"\nJumlah nilai yang hilang setelah penghapusan : {missing_values_after_drop}")

print("\nBeberapa baris pertama DataFrame setelah penghapusan nilai yang hilang : ")
display(df_dropped.head())

print(f"\nUkuran DataFrame setelah penghapusan nilai yang hilang : {df_dropped.shape}")
# Out:
# Jumlah nilai yang hilang sebelum penghapusan :  Age                    0
# Gender                 0
# Education Level        1
# Job Title              1
# Years of Experience    2
# Salary                 0
# Tahun_Daftar           2
# Bulan_Daftar           2
# Hari_Daftar            2
# dtype: int64
#
# Jumlah nilai yang hilang setelah penghapusan : 0
#
# Beberapa baris pertama DataFrame setelah penghapusan nilai yang hilang :
#    Age  Gender Education Level          Job Title  \
# 1   32    Male      Bachelor's  software engineer
# 2   28  Female        Master's       data analyst
# 3   45    Male             PhD     senior manager
# 4   36  Female      Bachelor's    sales associate
# 5   52    Male        Master's           director
#
#             Years of Experience    Salary  Tahun_Daftar  Bulan_Daftar  \
# 1 1970-01-01 00:00:00.000001970   90000.0        1970.0           1.0
# 2 1970-01-01 00:00:00.000001970   65000.0        1970.0           1.0
# ...

# %%
upper_limit = 20000000

rows_before_drop = len(df)
print(f"Jumlah baris sebelum menghapus outlier: {rows_before_drop}")

df_no_outliers = df[df['Salary'] <= upper_limit].copy()

rows_after_drop = len(df_no_outliers)
print(f"Jumlah baris setelah menghapus outlier di 'Salary': {rows_after_drop}")
print(f"Jumlah outlier yang dihapus: {rows_before_drop - rows_after_drop}")

print("\nStatistik deskriptif untuk 'Salary' setelah penghapusan outlier : ")
display(df_no_outliers['Salary'].describe())

print("\nBeberapa baris pertama DataFrame setelah penghapusan outlier : ")
display(df_no_outliers.head())
# Out:
# Jumlah baris sebelum menghapus outlier: 1794
# Jumlah baris setelah menghapus outlier di 'Salary': 1794
# Jumlah outlier yang dihapus: 0
#
# Statistik deskriptif untuk 'Salary' setelah penghapusan outlier :
# count       1794.000000
# mean      113726.860089
# std        55647.459021
# min          350.000000
# 25%        70000.000000
# 50%       110353.500000
# 75%       160000.000000
# max      1000000.000000
# Name: Salary, dtype: float64
# Beberapa baris pertama DataFrame setelah penghapusan outlier :
#    Age  Gender Education Level          Job Title  \
# 1   32    Male      Bachelor's  software engineer
# 2   28  Female        Master's       data analyst
# 3   45    Male             PhD     senior manager
# 4   36  Female      Bachelor's    sales associate
# 5   52    Male        Master's           director
#
#             Years of Experience    Salary  Tahun_Daftar  Bulan_Daftar  \
# 1 1970-01-01 00:00:00.000001970   90000.0        1970.0           1.0
# ...

# %% [markdown]
# **4. PRAKTIKUM 04**

# %%
df = df.reset_index(drop=True)
df.index = df.index + 1

# %%
display(df.head())
# Out:
#    Age  Gender Education Level          Job Title  \
# 1   32    Male      Bachelor's  software engineer
# 2   28  Female        Master's       data analyst
# 3   45    Male             PhD     senior manager
# 4   36  Female      Bachelor's    sales associate
# 5   52    Male        Master's           director
#
#             Years of Experience    Salary  Tahun_Daftar  Bulan_Daftar  \
# 1 1970-01-01 00:00:00.000001970   90000.0        1970.0           1.0
# 2 1970-01-01 00:00:00.000001970   65000.0        1970.0           1.0
# 3                           NaT  150000.0           NaN           NaN
# 4 1970-01-01 00:00:00.000001970   60000.0        1970.0           1.0
# 5 1970-01-01 00:00:00.000001970  200000.0        1970.0           1.0
#
#    Hari_Daftar
# 1          1.0
# 2          1.0
# 3          NaN
# 4          1.0
# 5          1.0

# %%
correlation = df['Salary'].corr(df['Years of Experience'])
print(f"Korelasi antara Salary dan Years of Experience : {correlation}")
# Out:
# Korelasi antara Salary dan Years of Experience : -0.01877989757145287

# %%
r_squared = correlation ** 2
print(f"Koefisien Determinasi (R-squared) antara Salary dan Years of Experience : {r_squared}")
# Out:
# Koefisien Determinasi (R-squared) antara Salary dan Years of Experience : 0.00035268455279426146

# %%
missing_values_before_drop = df.isnull().sum()
print(f"Jumlah nilai yang hilang sebelum penghapusan :  {missing_values_before_drop}")

df_dropped = df.dropna(subset=['Salary']).copy()

missing_values_after_drop = df_dropped['Salary'].isnull().sum()
print(f"\nJumlah nilai yang hilang setelah penghapusan : {missing_values_after_drop}")

df_dropped = df.dropna(subset=['Years of Experience']).copy()

missing_values_after_drop = df_dropped['Years of Experience'].isnull().sum()
print(f"\nJumlah nilai yang hilang setelah penghapusan : {missing_values_after_drop}")

print("\nBeberapa baris pertama DataFrame setelah penghapusan nilai yang hilang : ")
display(df_dropped.head())

print(f"\nUkuran DataFrame setelah penghapusan nilai yang hilang : {df_dropped.shape}")
# Out:
# Jumlah nilai yang hilang sebelum penghapusan :  Age                    0
# Gender                 0
# Education Level        1
# Job Title              1
# Years of Experience    2
# Salary                 0
# Tahun_Daftar           2
# Bulan_Daftar           2
# Hari_Daftar            2
# dtype: int64
#
# Jumlah nilai yang hilang setelah penghapusan : 0
#
# Jumlah nilai yang hilang setelah penghapusan : 0
#
# Beberapa baris pertama DataFrame setelah penghapusan nilai yang hilang :
#    Age  Gender Education Level          Job Title  \
# 1   32    Male      Bachelor's  software engineer
# 2   28  Female        Master's       data analyst
# 4   36  Female      Bachelor's    sales associate
# 5   52    Male        Master's           director
# 6   29    Male      Bachelor's  marketing analyst
#
#             Years of Experience    Salary  Tahun_Daftar  Bulan_Daftar  \
# 1 1970-01-01 00:00:00.000001970   90000.0        1970.0           1.0
# ...

# %% [markdown]
# **5. PRAKTIKUM 05**

# %%
df = df.reset_index(drop=True)
df.index = df.index + 1

# %%
df = df.rename(columns={'Years of Experience': 'Years_of_Experience'})
model = smf.ols('Salary ~ Years_of_Experience', data=df).fit()

# %%
import statsmodels.formula.api as smf

# The 'Years_of_Experience' column was converted to datetime objects in a previous step.
# For OLS regression, the dependent variable must be numerical.
# We will use 'Tahun_Daftar' (Year of Registration), which is a numerical representation,
# as the dependent variable instead of the datetime 'Years_of_Experience'.
model_salary_years = smf.ols('Tahun_Daftar ~ Salary', data=df).fit()

intercept_salary_years = model_salary_years.params['Intercept']
usia_coef_salary_years = model_salary_years.params['Salary']

ssr_salary_years = model_salary_years.ssr

print(f"Jumlah Kuadrat Residual (SSR) untuk model Tahun Daftar vs Gaji : {ssr_salary_years:.4f}")
print(f"Persamaan Garis Regresi (Tahun Daftar vs Gaji) : ")
print(f"Tahun_Daftar_prediksi = {intercept_salary_years:.4f} + ({usia_coef_salary_years:.4f}) * Gaji")
# Out:
# Jumlah Kuadrat Residual (SSR) untuk model Tahun Daftar vs Gaji : 0.0000
# Persamaan Garis Regresi (Tahun Daftar vs Gaji) :
# Tahun_Daftar_prediksi = 1970.0000 + (0.0000) * Gaji

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

shapiro_test= stats.shapiro(df['Salary'])
print(f"Hasil Uji Shapiro-Wilk: Statistik ={shapiro_test.statistic:.4f},p-value={shapiro_test.pvalue:.4f}")
alpha = 0.05
if shapiro_test.pvalue > alpha:
  print("Data kemungkinanan berdistribusi normal (gagal menolak H0)")
else:
  print("Data tidak berdistribusi normal (menolak H0)")

plt.figure(figsize=(8,6))
sns.histplot(df['Salary'], kde=True)
plt.title('Histogram of Salary')
plt.xlabel('Salary')
plt.ylabel('Frekuensi')
plt.show()
# Out:
# Hasil Uji Shapiro-Wilk: Statistik =0.8801,p-value=0.0000
# Data tidak berdistribusi normal (menolak H0)

# %% [markdown]
# **KESIMPULAN**
#
# *Dataset Salary_Data_Tugas berhasil dibaca dan dibersihkan melalui proses pengisian nilai hilang, penghapusan duplikasi, pembatasan outlier, serta standarisasi format data. Analisis deskriptif dan visualisasi menunjukkan bahwa data memiliki variasi besar, dengan distribusi gaji yang tidak normal. Hasil korelasi dan regresi menunjukkan hubungan yang sangat lemah antara Years of Experience dan Salary (r = -0.0187, R² = 0.00035), sehingga dapat disimpulkan bahwa pengalaman kerja tidak berpengaruh signifikan terhadap gaji dalam dataset ini, namun keseluruhan proses eksplorasi dan pembersihan data telah berhasil dilakukan dengan baik.*
